# %%
# Imports
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\brand\OneDrive\Documents\Bootcamp Projects\Capstone Project 2\Cleaned Data\cleaned_data")

# %%
df = df.loc[:, df.columns != 'Unnamed: 0']
df.head(5)
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii             2006    Sports  Nintendo
# 1         Mario Kart Wii      Wii             2008    Racing  Nintendo
# 2      Wii Sports Resort      Wii             2009    Sports  Nintendo
# 3  New Super Mario Bros.       DS             2006  Platform  Nintendo
# 4               Wii Play      Wii             2006      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53            76
# 1     15.68     12.76      3.79         3.29         35.52            82
# 2     15.61     10.93      3.28         2.95         32.77            80
# 3     11.28      9.14      6.50         2.88         29.80            89
# 4     13.96      9.18      2.93         2.84         28.92            58
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
# Basic summarization of data.
df2 = df.drop(["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"], axis=1)
df2.head()
df2.describe()
# Out:
#        Year_of_Release  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count      1688.000000   1688.000000   1688.000000   1688.000000  1688.000000
# mean       2008.402844      1.898199     75.927725     42.361967     7.568246
# std           4.332920      3.577727     11.476560     22.170379     1.132517
# min        1994.000000      0.040000     33.000000      4.000000     1.700000
# 25%        2006.000000      0.410000     69.000000     25.000000     7.000000
# 50%        2009.000000      0.910000     77.000000     40.000000     7.800000
# 75%        2012.000000      2.040000     84.000000     57.250000     8.400000
# max        2016.000000     82.530000     98.000000    113.000000     9.600000
#
#          User_Count
# count   1688.000000
# mean     325.350118
# std      738.857794
# min        4.000000
# 25%       36.000000
# 50%       87.000000
# 75%      263.000000
# max    10179.000000

# %%
df2.sample(n=5)
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 1295       Advance Wars: Dual Strike       DS             2005      Strategy
# 431        Kingdom Hearts 358/2 Days       DS             2009  Role-Playing
# 1236              Samurai Warriors 3      Wii             2009        Action
# 386               Forza Motorsport 5     XOne             2013        Racing
# 74    Uncharted 3: Drake's Deception      PS3             2011        Action
#
#                         Publisher  Global_Sales  Critic_Score  Critic_Count  \
# 1295                     Nintendo          0.39            90            49
# 431                   Square Enix          1.98            75            53
# 1236                     Nintendo          0.44            55            26
# 386        Microsoft Game Studios          2.20            79            76
# 74    Sony Computer Entertainment          6.74            92            97
#
# ...

# %%
# heatmap
plt.figure(figsize=(10,5))
columns_to_include = ['Year_of_Release','Global_Sales','Critic_Score','Critic_Count',
                      'User_Score','User_Count']
df_heat = df2[columns_to_include]
sns.heatmap(data= df_heat.corr(), annot=True, cmap='coolwarm',linewidth=.5)

# Not noting any strong correlation between any variables or features.
# Out:
# <Axes: >

# %%
sns.pairplot(df2, hue='Global_Sales', height=2, aspect=2)
# Out:
# C:\Users\brand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\brand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\brand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# The next 6 cells are generating decriptive discriptive statistics for differnts groups. Really interested in sales performance for each group. 
# The PLaystion platorm is the strongest, PS1,PS2,PS2,"ect", including the PSP and PSV. Surpring considering nintendoes market share by publisher.
platform_descriptions = df2.groupby('Platform')
for platform,group in platform_descriptions:
    print(f"Descriptive statistics for Platfroms: {platform}")
    print(group.describe())
    print("\n")

grouped_sales = df2.groupby('Platform')["Global_Sales"].sum()
print(f"Total gloabl Sales by {grouped_sales}")

plt.figure(figsize=(10, 6))
grouped_sales.plot(kind='bar', color='skyblue')
plt.title('Total Global Sales by Platform')
plt.xlabel('Platform')
plt.ylabel('Total Global Sales')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
# Out:
# Descriptive statistics for Platfroms: 3DS
#        Year_of_Release  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# count        80.000000      80.00000     80.000000     80.000000   80.000000
# mean       2012.637500       1.32900     71.350000     46.012500    7.278750
# std           1.585087       2.32185     11.812994     22.175647    1.221609
# min        2011.000000       0.11000     43.000000      4.000000    3.300000
# 25%        2011.000000       0.35250     63.250000     29.750000    6.475000
# 50%        2012.000000       0.49000     73.500000     45.000000    7.600000
# 75%        2014.000000       1.13250     80.000000     69.000000    8.200000
# max        2016.000000      12.66000     92.000000     82.000000    9.100000
#
#        User_Count
# count    80.00000
# mean    162.67500
# std     224.18436
# min       8.00000
# 25%      28.00000
# 50%      87.50000
# 75%     181.75000
# max    1130.00000
#
#
# Descriptive statistics for Platfroms: DC
# ...

# %%
#Grouping by genre. Action has a firm lead followed by shooter. Makes since considering the Halo and Call of Duty Franchises.
#Sports is third considering the Maden franchise and the like.
genre_descriptions = df2.groupby('Genre')
for genre,group in genre_descriptions:
    print(f"Descriptive statistics for genre: {genre}")
    print(group.describe())
    print("\n") 

grouped_sales = df2.groupby('Genre')["Global_Sales"].sum()
print(f"Total gloabl Sales by {grouped_sales}")

plt.figure(figsize=(10, 6))
grouped_sales.plot(kind='bar', color='skyblue')
plt.title('Total Global Sales by Genre')
plt.xlabel('Genre')
plt.ylabel('Total Global Sales')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
# Out:
# Descriptive statistics for genre: Action
#        Year_of_Release  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# count       431.000000    431.000000    431.000000    431.000000  431.000000
# mean       2009.245940      1.699814     74.962877     44.610209    7.552436
# std           4.284078      2.479510     12.780200     23.929573    1.118174
# min        1996.000000      0.070000     33.000000      4.000000    1.700000
# 25%        2007.000000      0.385000     66.000000     26.000000    7.000000
# 50%        2010.000000      0.900000     76.000000     42.000000    7.700000
# 75%        2012.000000      1.865000     84.000000     63.000000    8.300000
# max        2016.000000     21.040000     98.000000    106.000000    9.400000
#
#         User_Count
# count   431.000000
# mean    434.554524
# std     862.100971
# min       6.000000
# 25%      41.000000
# 50%     136.000000
# 75%     411.000000
# max    8003.000000
#
#
# Descriptive statistics for genre: Adventure
# ...

# %%
#Grouping by Publisher, Nintendo dwarfs the market nearly twice over. Surprised Sony the maker of the playstion platforms is not higher.
publisher_descriptions = df2.groupby('Publisher')
for publisher,group in publisher_descriptions:
    print(f"Descriptive statistics for publisher: {publisher}")
    print(group.describe())
    print("\n") 

grouped_sales = df2.groupby('Publisher')["Global_Sales"].sum()
print(f"Total gloabl Sales by {grouped_sales}")

plt.figure(figsize=(24, 12))
grouped_sales.plot(kind='barh', color='skyblue')
plt.title('Total Global Sales by publisher')
plt.xlabel('Genre')
plt.ylabel('Total Global Sales')
plt.xticks(rotation=90)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
# Out:
# Descriptive statistics for publisher: 505 Games
#        Year_of_Release  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# count        11.000000     11.000000     11.000000     11.000000   11.000000
# mean       2008.636364      1.558182     63.636364     25.090909    6.854545
# std           2.656039      1.751004     10.528749     10.653211    1.841393
# min        2005.000000      0.180000     38.000000     12.000000    3.000000
# 25%        2007.000000      0.330000     60.500000     16.500000    6.050000
# 50%        2008.000000      0.870000     65.000000     21.000000    7.200000
# 75%        2010.500000      2.120000     68.500000     36.000000    7.950000
# max        2013.000000      5.630000     81.000000     39.000000    9.300000
#
#        User_Count
# count   11.000000
# mean    38.090909
# std     41.324217
# min      4.000000
# 25%     12.000000
# 50%     21.000000
# 75%     50.500000
# max    131.000000
#
#
# ...

# %%
#Grouping by developer, many uinque vaues in this category. 
developer_descriptions = df2.groupby('Developer')
for developer,group in developer_descriptions:
    print(f"Descriptive statistics for developer: {developer}")
    print(group.describe())
    print("\n") 

grouped_sales = df2.groupby('Developer')["Global_Sales"].sum()
print(f"Total gloabl Sales by {grouped_sales}")

# I did not make a plot for each developer as there are early 500 unique developers. Wil reqire more EDA with something more.
print("Total amount of developers:",len(df2['Developer'].unique()))
# Out:
# Descriptive statistics for developer: 2K Australia
#        Year_of_Release  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# count              2.0      2.000000       2.00000      2.000000    2.000000
# mean            2014.0      0.665000      75.50000     20.000000    6.350000
# std                0.0      0.077782       2.12132      5.656854    0.070711
# min             2014.0      0.610000      74.00000     16.000000    6.300000
# 25%             2014.0      0.637500      74.75000     18.000000    6.325000
# 50%             2014.0      0.665000      75.50000     20.000000    6.350000
# 75%             2014.0      0.692500      76.25000     22.000000    6.375000
# max             2014.0      0.720000      77.00000     24.000000    6.400000
#
#        User_Count
# count     2.00000
# mean    145.50000
# std      21.92031
# min     130.00000
# 25%     137.75000
# 50%     145.50000
# 75%     153.25000
# max     161.00000
#
#
# ...

# %%
# Grouping by Rating, An E rating has the highest share over ay other rating
rating_descriptions = df2.groupby('Rating')
for rating,group in rating_descriptions:
    print(f"Descriptive statistics for rating: {rating}")
    print(group.describe())
    print("\n") 

grouped_sales = df2.groupby('Rating')["Global_Sales"].sum()
print(f"Total gloabl Sales by {grouped_sales}")

plt.figure(figsize=(10, 6))
grouped_sales.plot(kind='bar', color='skyblue')
plt.title('Total Global Sales by rating')
plt.xlabel('Rating')
plt.ylabel('Total Global Sales')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
# Out:
# Descriptive statistics for rating: E
#        Year_of_Release  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# count       438.000000    438.000000    438.000000    438.000000  438.000000
# mean       2007.038813      2.828516     76.851598     36.536530    7.645662
# std           4.374447      5.823174     10.445604     20.496186    1.108142
# min        1997.000000      0.040000     41.000000      4.000000    4.000000
# 25%        2004.000000      0.582500     70.000000     20.000000    7.000000
# 50%        2007.000000      1.300000     78.000000     33.000000    7.900000
# 75%        2010.000000      2.890000     84.000000     49.000000    8.500000
# max        2016.000000     82.530000     97.000000     90.000000    9.600000
#
#         User_Count
# count   438.000000
# mean    153.621005
# std     355.135708
# min       4.000000
# 25%      24.000000
# 50%      51.000000
# 75%     133.750000
# max    5311.000000
#
#
# Descriptive statistics for rating: E10+
# ...

# %%
# Out:
# 499
